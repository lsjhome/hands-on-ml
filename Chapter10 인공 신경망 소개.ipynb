# %% [markdown]
# # 10장 인공 신경망 소개

# %%
# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "ann"

def save_fig(fig_id, tight_layout=True):
    path = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID, fig_id + ".png")
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format='png', dpi=300)

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.linear_model import Perceptron

iris = load_iris()
X = iris.data[:, (2, 3)]  # 꽃잎의 길이와 너비
y = (iris.target == 0).astype(np.int)

per_clf = Perceptron(random_state=42)
per_clf.fit(X, y)

y_pred = per_clf.predict([[2, 0.5]])
# Out:
# /Users/smfc/.pyenv/versions/3.6.4/envs/hands-on/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.perceptron.Perceptron'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
y_pred
# Out:
# array([1])

# %% [markdown]
# ## 10.2 텐서플로의 고수준 API로 다층 퍼셉트론 훈련하기

# %%
import tensorflow as tf

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
X_train = X_train.astype(np.float32).reshape(-1, 28*28) / 255.0
X_test = X_test.astype(np.float32).reshape(-1, 28*28) / 255.0
y_train = y_train.astype(np.int32)
y_test = y_test.astype(np.int32)
X_valid, X_train = X_train[:5000], X_train[5000:]
y_valid, y_train = y_train[:5000], y_train[5000:]

# %%
feature_cols = [tf.feature_column.numeric_column("X", shape=[28 * 28])]
dnn_clf = tf.estimator.DNNClassifier(hidden_units=[300,100], n_classes=10,
                                     feature_columns=feature_cols)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/1g/rftmf6dn1g5dkx80h4m74syc0000gn/T/tmpo3tv44x1
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/1g/rftmf6dn1g5dkx80h4m74syc0000gn/T/tmpo3tv44x1', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x10b781278>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"X": X_train}, y=y_train, num_epochs=40, batch_size=50, shuffle=True)
dnn_clf.train(input_fn=input_fn)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/1g/rftmf6dn1g5dkx80h4m74syc0000gn/T/tmpo3tv44x1/model.ckpt.
# INFO:tensorflow:loss = 114.95188, step = 1
# INFO:tensorflow:global_step/sec: 394.756
# INFO:tensorflow:loss = 26.389175, step = 101 (0.255 sec)
# INFO:tensorflow:global_step/sec: 485.587
# INFO:tensorflow:loss = 18.214302, step = 201 (0.205 sec)
# INFO:tensorflow:global_step/sec: 483.693
# INFO:tensorflow:loss = 5.986426, step = 301 (0.207 sec)
# INFO:tensorflow:global_step/sec: 464.138
# INFO:tensorflow:loss = 15.497122, step = 401 (0.216 sec)
# INFO:tensorflow:global_step/sec: 468.428
# INFO:tensorflow:loss = 9.043336, step = 501 (0.213 sec)
# INFO:tensorflow:global_step/sec: 486.677
# INFO:tensorflow:loss = 3.275099, step = 601 (0.206 sec)
# INFO:tensorflow:global_step/sec: 463.641
# INFO:tensorflow:loss = 2.3964906, step = 701 (0.215 sec)
# INFO:tensorflow:global_step/sec: 454.165
# INFO:tensorflow:loss = 14.491355, step = 801 (0.220 sec)
# INFO:tensorflow:global_step/sec: 468.565
# INFO:tensorflow:loss = 6.361579, step = 901 (0.213 sec)
# INFO:tensorflow:global_step/sec: 527.64
# INFO:tensorflow:loss = 0.8349339, step = 1001 (0.189 sec)
# INFO:tensorflow:global_step/sec: 477.847
# INFO:tensorflow:loss = 5.2091312, step = 1101 (0.209 sec)
# INFO:tensorflow:global_step/sec: 463.495
# INFO:tensorflow:loss = 1.9974825, step = 1201 (0.216 sec)
# INFO:tensorflow:global_step/sec: 487.904
# INFO:tensorflow:loss = 1.5402875, step = 1301 (0.205 sec)
# INFO:tensorflow:global_step/sec: 495.069
# INFO:tensorflow:loss = 3.9667044, step = 1401 (0.202 sec)
# INFO:tensorflow:global_step/sec: 509.775
# INFO:tensorflow:loss = 5.845046, step = 1501 (0.196 sec)
# INFO:tensorflow:global_step/sec: 489.548
# INFO:tensorflow:loss = 17.843102, step = 1601 (0.204 sec)
# INFO:tensorflow:global_step/sec: 479.612
# INFO:tensorflow:loss = 0.78175044, step = 1701 (0.209 sec)
# INFO:tensorflow:global_step/sec: 481.112
# INFO:tensorflow:loss = 9.445105, step = 1801 (0.208 sec)
# INFO:tensorflow:global_step/sec: 463.192
# INFO:tensorflow:loss = 6.344072, step = 1901 (0.216 sec)
# INFO:tensorflow:global_step/sec: 492.121
# INFO:tensorflow:loss = 3.991342, step = 2001 (0.203 sec)
# INFO:tensorflow:global_step/sec: 488.995
# INFO:tensorflow:loss = 1.3824575, step = 2101 (0.204 sec)
# INFO:tensorflow:global_step/sec: 501.907
# INFO:tensorflow:loss = 2.6243958, step = 2201 (0.199 sec)
# INFO:tensorflow:global_step/sec: 490.143
# INFO:tensorflow:loss = 3.4331594, step = 2301 (0.204 sec)
# INFO:tensorflow:global_step/sec: 506.489
# INFO:tensorflow:loss = 0.28128532, step = 2401 (0.198 sec)
# INFO:tensorflow:global_step/sec: 500.879
# INFO:tensorflow:loss = 1.8371149, step = 2501 (0.199 sec)
# INFO:tensorflow:global_step/sec: 490.456
# INFO:tensorflow:loss = 2.8522944, step = 2601 (0.204 sec)
# INFO:tensorflow:global_step/sec: 418.976
# INFO:tensorflow:loss = 0.6358566, step = 2701 (0.239 sec)
# INFO:tensorflow:global_step/sec: 458.461
# INFO:tensorflow:loss = 10.669444, step = 2801 (0.218 sec)
# INFO:tensorflow:global_step/sec: 456.536
# INFO:tensorflow:loss = 1.3163909, step = 2901 (0.219 sec)
# INFO:tensorflow:global_step/sec: 456.976
# INFO:tensorflow:loss = 7.2774353, step = 3001 (0.219 sec)
# INFO:tensorflow:global_step/sec: 467.753
# INFO:tensorflow:loss = 0.92645246, step = 3101 (0.214 sec)
# INFO:tensorflow:global_step/sec: 466.357
# INFO:tensorflow:loss = 4.713763, step = 3201 (0.214 sec)
# INFO:tensorflow:global_step/sec: 486.895
# INFO:tensorflow:loss = 2.1962352, step = 3301 (0.205 sec)
# INFO:tensorflow:global_step/sec: 475.22
# INFO:tensorflow:loss = 2.6314328, step = 3401 (0.210 sec)
# INFO:tensorflow:global_step/sec: 479.481
# INFO:tensorflow:loss = 4.414591, step = 3501 (0.209 sec)
# INFO:tensorflow:global_step/sec: 489.836
# INFO:tensorflow:loss = 3.1693935, step = 3601 (0.204 sec)
# INFO:tensorflow:global_step/sec: 469.771
# INFO:tensorflow:loss = 4.4387755, step = 3701 (0.213 sec)
# INFO:tensorflow:global_step/sec: 479.991
# INFO:tensorflow:loss = 4.2827606, step = 3801 (0.208 sec)
# INFO:tensorflow:global_step/sec: 500.539
# INFO:tensorflow:loss = 0.5003986, step = 3901 (0.200 sec)
# INFO:tensorflow:global_step/sec: 476.844
# INFO:tensorflow:loss = 0.87583935, step = 4001 (0.210 sec)
# INFO:tensorflow:global_step/sec: 492.678
# INFO:tensorflow:loss = 1.1335272, step = 4101 (0.203 sec)
# INFO:tensorflow:global_step/sec: 490.355
# INFO:tensorflow:loss = 1.2003003, step = 4201 (0.204 sec)
# INFO:tensorflow:global_step/sec: 479.515
# INFO:tensorflow:loss = 4.9653697, step = 4301 (0.209 sec)
# INFO:tensorflow:global_step/sec: 468.727
# INFO:tensorflow:loss = 1.9013648, step = 4401 (0.213 sec)
# INFO:tensorflow:global_step/sec: 463.891
# INFO:tensorflow:loss = 1.4844607, step = 4501 (0.216 sec)
# INFO:tensorflow:global_step/sec: 485.754
# INFO:tensorflow:loss = 0.13103446, step = 4601 (0.206 sec)
# INFO:tensorflow:global_step/sec: 489.637
# INFO:tensorflow:loss = 0.46009308, step = 4701 (0.204 sec)
# INFO:tensorflow:global_step/sec: 454.172
# INFO:tensorflow:loss = 0.1817253, step = 4801 (0.220 sec)
# INFO:tensorflow:global_step/sec: 464.708
# INFO:tensorflow:loss = 0.17847587, step = 4901 (0.215 sec)
# INFO:tensorflow:global_step/sec: 460.7
# INFO:tensorflow:loss = 0.7018966, step = 5001 (0.217 sec)
# INFO:tensorflow:global_step/sec: 495.022
# INFO:tensorflow:loss = 5.207254, step = 5101 (0.202 sec)
# INFO:tensorflow:global_step/sec: 490.843
# INFO:tensorflow:loss = 1.3196332, step = 5201 (0.204 sec)
# INFO:tensorflow:global_step/sec: 469.433
# INFO:tensorflow:loss = 0.3348996, step = 5301 (0.213 sec)
# INFO:tensorflow:global_step/sec: 473.382
# INFO:tensorflow:loss = 5.6122007, step = 5401 (0.211 sec)
# INFO:tensorflow:global_step/sec: 491.493
# INFO:tensorflow:loss = 3.2809374, step = 5501 (0.203 sec)
# INFO:tensorflow:global_step/sec: 479.558
# INFO:tensorflow:loss = 2.0337353, step = 5601 (0.209 sec)
# INFO:tensorflow:global_step/sec: 479.378
# INFO:tensorflow:loss = 0.83336556, step = 5701 (0.209 sec)
# INFO:tensorflow:global_step/sec: 473.599
# INFO:tensorflow:loss = 1.0697098, step = 5801 (0.212 sec)
# INFO:tensorflow:global_step/sec: 457.737
# INFO:tensorflow:loss = 0.19249387, step = 5901 (0.218 sec)
# INFO:tensorflow:global_step/sec: 471.225
# INFO:tensorflow:loss = 1.585635, step = 6001 (0.212 sec)
# INFO:tensorflow:global_step/sec: 490.244
# INFO:tensorflow:loss = 0.28223294, step = 6101 (0.204 sec)
# INFO:tensorflow:global_step/sec: 486.275
# INFO:tensorflow:loss = 0.32542825, step = 6201 (0.206 sec)
# INFO:tensorflow:global_step/sec: 493.976
# INFO:tensorflow:loss = 2.31172, step = 6301 (0.203 sec)
# INFO:tensorflow:global_step/sec: 490.694
# INFO:tensorflow:loss = 1.3897643, step = 6401 (0.203 sec)
# INFO:tensorflow:global_step/sec: 491.976
# INFO:tensorflow:loss = 0.5690382, step = 6501 (0.203 sec)
# INFO:tensorflow:global_step/sec: 491.386
# INFO:tensorflow:loss = 0.8109145, step = 6601 (0.204 sec)
# INFO:tensorflow:global_step/sec: 487.052
# INFO:tensorflow:loss = 0.19815445, step = 6701 (0.205 sec)
# INFO:tensorflow:global_step/sec: 527.612
# INFO:tensorflow:loss = 0.032283798, step = 6801 (0.189 sec)
# INFO:tensorflow:global_step/sec: 510.165
# INFO:tensorflow:loss = 0.09470574, step = 6901 (0.196 sec)
# INFO:tensorflow:global_step/sec: 506.278
# INFO:tensorflow:loss = 0.08438949, step = 7001 (0.198 sec)
# INFO:tensorflow:global_step/sec: 525.461
# INFO:tensorflow:loss = 0.42296934, step = 7101 (0.190 sec)
# INFO:tensorflow:global_step/sec: 499.446
# INFO:tensorflow:loss = 0.22086784, step = 7201 (0.200 sec)
# INFO:tensorflow:global_step/sec: 477.746
# INFO:tensorflow:loss = 0.35901505, step = 7301 (0.209 sec)
# INFO:tensorflow:global_step/sec: 479.929
# INFO:tensorflow:loss = 3.8653305, step = 7401 (0.208 sec)
# INFO:tensorflow:global_step/sec: 494.781
# INFO:tensorflow:loss = 1.1045895, step = 7501 (0.202 sec)
# INFO:tensorflow:global_step/sec: 495.189
# INFO:tensorflow:loss = 1.1330392, step = 7601 (0.202 sec)
# INFO:tensorflow:global_step/sec: 467.246
# INFO:tensorflow:loss = 0.15152796, step = 7701 (0.214 sec)
# INFO:tensorflow:global_step/sec: 486.95
# INFO:tensorflow:loss = 0.3777509, step = 7801 (0.205 sec)
# INFO:tensorflow:global_step/sec: 483.115
# INFO:tensorflow:loss = 0.48015937, step = 7901 (0.207 sec)
# INFO:tensorflow:global_step/sec: 480.635
# INFO:tensorflow:loss = 0.23383081, step = 8001 (0.208 sec)
# INFO:tensorflow:global_step/sec: 498.869
# INFO:tensorflow:loss = 1.9241284, step = 8101 (0.201 sec)
# INFO:tensorflow:global_step/sec: 495.907
# INFO:tensorflow:loss = 0.3451515, step = 8201 (0.202 sec)
# INFO:tensorflow:global_step/sec: 491.586
# INFO:tensorflow:loss = 0.29091355, step = 8301 (0.203 sec)
# INFO:tensorflow:global_step/sec: 471.785
# INFO:tensorflow:loss = 0.9153074, step = 8401 (0.212 sec)
# INFO:tensorflow:global_step/sec: 461.174
# INFO:tensorflow:loss = 3.2988763, step = 8501 (0.217 sec)
# INFO:tensorflow:global_step/sec: 484.533
# INFO:tensorflow:loss = 0.46341488, step = 8601 (0.206 sec)
# INFO:tensorflow:global_step/sec: 494.028
# INFO:tensorflow:loss = 1.1164093, step = 8701 (0.202 sec)
# INFO:tensorflow:global_step/sec: 516.188
# INFO:tensorflow:loss = 1.1223154, step = 8801 (0.194 sec)
# INFO:tensorflow:global_step/sec: 468.371
# INFO:tensorflow:loss = 1.6284499, step = 8901 (0.214 sec)
# INFO:tensorflow:global_step/sec: 496.046
# INFO:tensorflow:loss = 0.3301569, step = 9001 (0.201 sec)
# INFO:tensorflow:global_step/sec: 519.775
# INFO:tensorflow:loss = 0.08577343, step = 9101 (0.192 sec)
# INFO:tensorflow:global_step/sec: 523.181
# INFO:tensorflow:loss = 0.15446801, step = 9201 (0.191 sec)
# INFO:tensorflow:global_step/sec: 522.243
# INFO:tensorflow:loss = 0.6526097, step = 9301 (0.191 sec)
# INFO:tensorflow:global_step/sec: 511.151
# INFO:tensorflow:loss = 0.70175725, step = 9401 (0.196 sec)
# INFO:tensorflow:global_step/sec: 460.931
# INFO:tensorflow:loss = 0.6551857, step = 9501 (0.217 sec)
# INFO:tensorflow:global_step/sec: 497.483
# INFO:tensorflow:loss = 0.19057256, step = 9601 (0.201 sec)
# INFO:tensorflow:global_step/sec: 433.702
# INFO:tensorflow:loss = 0.09629752, step = 9701 (0.231 sec)
# INFO:tensorflow:global_step/sec: 438.024
# INFO:tensorflow:loss = 0.3151111, step = 9801 (0.228 sec)
# INFO:tensorflow:global_step/sec: 500.899
# INFO:tensorflow:loss = 0.08351073, step = 9901 (0.199 sec)
# INFO:tensorflow:global_step/sec: 500.173
# INFO:tensorflow:loss = 4.525066, step = 10001 (0.200 sec)
# INFO:tensorflow:global_step/sec: 513.885
# INFO:tensorflow:loss = 0.3766222, step = 10101 (0.195 sec)
# INFO:tensorflow:global_step/sec: 508.371
# INFO:tensorflow:loss = 0.045171175, step = 10201 (0.197 sec)
# INFO:tensorflow:global_step/sec: 497.851
# INFO:tensorflow:loss = 0.15932895, step = 10301 (0.201 sec)
# INFO:tensorflow:global_step/sec: 504.144
# INFO:tensorflow:loss = 0.15899532, step = 10401 (0.198 sec)
# INFO:tensorflow:global_step/sec: 477.667
# INFO:tensorflow:loss = 0.3142754, step = 10501 (0.210 sec)
# INFO:tensorflow:global_step/sec: 444.223
# INFO:tensorflow:loss = 0.20797518, step = 10601 (0.225 sec)
# INFO:tensorflow:global_step/sec: 438.225
# INFO:tensorflow:loss = 7.354462, step = 10701 (0.228 sec)
# INFO:tensorflow:global_step/sec: 495.937
# INFO:tensorflow:loss = 0.04397656, step = 10801 (0.202 sec)
# INFO:tensorflow:global_step/sec: 492.011
# INFO:tensorflow:loss = 0.2927448, step = 10901 (0.203 sec)
# INFO:tensorflow:global_step/sec: 499.858
# INFO:tensorflow:loss = 0.60162836, step = 11001 (0.200 sec)
# INFO:tensorflow:global_step/sec: 483.012
# INFO:tensorflow:loss = 0.8471414, step = 11101 (0.207 sec)
# INFO:tensorflow:global_step/sec: 495.624
# INFO:tensorflow:loss = 0.34172323, step = 11201 (0.202 sec)
# INFO:tensorflow:global_step/sec: 457.584
# INFO:tensorflow:loss = 2.0839708, step = 11301 (0.219 sec)
# INFO:tensorflow:global_step/sec: 478.103
# INFO:tensorflow:loss = 0.21593578, step = 11401 (0.208 sec)
# INFO:tensorflow:global_step/sec: 487.778
# INFO:tensorflow:loss = 0.055022124, step = 11501 (0.205 sec)
# INFO:tensorflow:global_step/sec: 490.389
# INFO:tensorflow:loss = 0.0994644, step = 11601 (0.204 sec)
# INFO:tensorflow:global_step/sec: 446.018
# INFO:tensorflow:loss = 0.11083551, step = 11701 (0.224 sec)
# INFO:tensorflow:global_step/sec: 447.413
# INFO:tensorflow:loss = 0.13544796, step = 11801 (0.223 sec)
# INFO:tensorflow:global_step/sec: 452.47
# INFO:tensorflow:loss = 0.022207804, step = 11901 (0.221 sec)
# INFO:tensorflow:global_step/sec: 471.034
# INFO:tensorflow:loss = 0.32231227, step = 12001 (0.212 sec)
# INFO:tensorflow:global_step/sec: 455.737
# INFO:tensorflow:loss = 0.13771205, step = 12101 (0.221 sec)
# INFO:tensorflow:global_step/sec: 471.467
# INFO:tensorflow:loss = 0.12654783, step = 12201 (0.211 sec)
# INFO:tensorflow:global_step/sec: 475.792
# INFO:tensorflow:loss = 0.07891899, step = 12301 (0.211 sec)
# INFO:tensorflow:global_step/sec: 468.312
# INFO:tensorflow:loss = 0.08878708, step = 12401 (0.213 sec)
# INFO:tensorflow:global_step/sec: 495.361
# INFO:tensorflow:loss = 0.13921085, step = 12501 (0.202 sec)
# INFO:tensorflow:global_step/sec: 471.391
# INFO:tensorflow:loss = 0.66890883, step = 12601 (0.213 sec)
# INFO:tensorflow:global_step/sec: 468.406
# INFO:tensorflow:loss = 0.28220576, step = 12701 (0.213 sec)
# INFO:tensorflow:global_step/sec: 489.216
# INFO:tensorflow:loss = 0.16358936, step = 12801 (0.205 sec)
# INFO:tensorflow:global_step/sec: 489.773
# INFO:tensorflow:loss = 0.21478559, step = 12901 (0.204 sec)
# INFO:tensorflow:global_step/sec: 494.557
# INFO:tensorflow:loss = 0.28357798, step = 13001 (0.202 sec)
# INFO:tensorflow:global_step/sec: 515.318
# INFO:tensorflow:loss = 0.095593385, step = 13101 (0.194 sec)
# INFO:tensorflow:global_step/sec: 506.585
# INFO:tensorflow:loss = 0.013912988, step = 13201 (0.198 sec)
# INFO:tensorflow:global_step/sec: 497.021
# INFO:tensorflow:loss = 0.2785554, step = 13301 (0.201 sec)
# INFO:tensorflow:global_step/sec: 485.774
# INFO:tensorflow:loss = 0.6326033, step = 13401 (0.206 sec)
# INFO:tensorflow:global_step/sec: 439.684
# INFO:tensorflow:loss = 0.15578999, step = 13501 (0.227 sec)
# INFO:tensorflow:global_step/sec: 479.704
# INFO:tensorflow:loss = 0.22457238, step = 13601 (0.209 sec)
# INFO:tensorflow:global_step/sec: 479.858
# INFO:tensorflow:loss = 0.16105486, step = 13701 (0.208 sec)
# INFO:tensorflow:global_step/sec: 488.632
# INFO:tensorflow:loss = 0.19733825, step = 13801 (0.205 sec)
# INFO:tensorflow:global_step/sec: 491.678
# INFO:tensorflow:loss = 0.20830238, step = 13901 (0.203 sec)
# INFO:tensorflow:global_step/sec: 460.481
# INFO:tensorflow:loss = 0.13275196, step = 14001 (0.217 sec)
# INFO:tensorflow:global_step/sec: 481.807
# INFO:tensorflow:loss = 0.12512548, step = 14101 (0.207 sec)
# INFO:tensorflow:global_step/sec: 348.52
# INFO:tensorflow:loss = 0.6527422, step = 14201 (0.288 sec)
# INFO:tensorflow:global_step/sec: 472.597
# INFO:tensorflow:loss = 0.15131588, step = 14301 (0.211 sec)
# INFO:tensorflow:global_step/sec: 469.263
# INFO:tensorflow:loss = 0.07547421, step = 14401 (0.213 sec)
# INFO:tensorflow:global_step/sec: 439.498
# INFO:tensorflow:loss = 0.07078474, step = 14501 (0.228 sec)
# INFO:tensorflow:global_step/sec: 439.049
# INFO:tensorflow:loss = 0.012109735, step = 14601 (0.228 sec)
# INFO:tensorflow:global_step/sec: 457.488
# INFO:tensorflow:loss = 0.081012614, step = 14701 (0.219 sec)
# INFO:tensorflow:global_step/sec: 486.658
# INFO:tensorflow:loss = 0.29022026, step = 14801 (0.205 sec)
# INFO:tensorflow:global_step/sec: 488.236
# INFO:tensorflow:loss = 0.06565573, step = 14901 (0.205 sec)
# INFO:tensorflow:global_step/sec: 483.272
# INFO:tensorflow:loss = 0.0963024, step = 15001 (0.207 sec)
# INFO:tensorflow:global_step/sec: 467.681
# INFO:tensorflow:loss = 0.15928356, step = 15101 (0.214 sec)
# INFO:tensorflow:global_step/sec: 428.172
# INFO:tensorflow:loss = 0.15982623, step = 15201 (0.234 sec)
# INFO:tensorflow:global_step/sec: 473.889
# INFO:tensorflow:loss = 0.22646344, step = 15301 (0.211 sec)
# INFO:tensorflow:global_step/sec: 465.385
# INFO:tensorflow:loss = 0.18627901, step = 15401 (0.215 sec)
# INFO:tensorflow:global_step/sec: 414.984
# INFO:tensorflow:loss = 0.26662973, step = 15501 (0.241 sec)
# INFO:tensorflow:global_step/sec: 451.231
# INFO:tensorflow:loss = 0.13357887, step = 15601 (0.221 sec)
# INFO:tensorflow:global_step/sec: 496.287
# INFO:tensorflow:loss = 0.04117465, step = 15701 (0.202 sec)
# INFO:tensorflow:global_step/sec: 474.872
# INFO:tensorflow:loss = 0.09156537, step = 15801 (0.211 sec)
# INFO:tensorflow:global_step/sec: 472.052
# INFO:tensorflow:loss = 0.09067625, step = 15901 (0.212 sec)
# INFO:tensorflow:global_step/sec: 477.555
# INFO:tensorflow:loss = 0.055424284, step = 16001 (0.209 sec)
# INFO:tensorflow:global_step/sec: 489.505
# INFO:tensorflow:loss = 0.019529173, step = 16101 (0.204 sec)
# INFO:tensorflow:global_step/sec: 460.369
# INFO:tensorflow:loss = 0.13587135, step = 16201 (0.218 sec)
# INFO:tensorflow:global_step/sec: 492.24
# INFO:tensorflow:loss = 0.035015717, step = 16301 (0.203 sec)
# INFO:tensorflow:global_step/sec: 484.334
# INFO:tensorflow:loss = 0.07064167, step = 16401 (0.206 sec)
# INFO:tensorflow:global_step/sec: 486.89
# INFO:tensorflow:loss = 0.024519447, step = 16501 (0.206 sec)
# INFO:tensorflow:global_step/sec: 493.178
# INFO:tensorflow:loss = 0.22345519, step = 16601 (0.203 sec)
# INFO:tensorflow:global_step/sec: 406.859
# INFO:tensorflow:loss = 0.03552191, step = 16701 (0.246 sec)
# INFO:tensorflow:global_step/sec: 483.601
# INFO:tensorflow:loss = 0.01463558, step = 16801 (0.207 sec)
# INFO:tensorflow:global_step/sec: 340.832
# INFO:tensorflow:loss = 0.2144121, step = 16901 (0.294 sec)
# INFO:tensorflow:global_step/sec: 367.415
# INFO:tensorflow:loss = 0.13045144, step = 17001 (0.272 sec)
# INFO:tensorflow:global_step/sec: 368.164
# INFO:tensorflow:loss = 0.024027836, step = 17101 (0.271 sec)
# INFO:tensorflow:global_step/sec: 391.98
# INFO:tensorflow:loss = 0.012255209, step = 17201 (0.256 sec)
# INFO:tensorflow:global_step/sec: 319.872
# INFO:tensorflow:loss = 0.26663366, step = 17301 (0.312 sec)
# INFO:tensorflow:global_step/sec: 337.214
# INFO:tensorflow:loss = 0.035421308, step = 17401 (0.297 sec)
# INFO:tensorflow:global_step/sec: 370.116
# INFO:tensorflow:loss = 0.008648506, step = 17501 (0.270 sec)
# INFO:tensorflow:global_step/sec: 421.429
# INFO:tensorflow:loss = 0.06687905, step = 17601 (0.237 sec)
# INFO:tensorflow:global_step/sec: 370.468
# INFO:tensorflow:loss = 0.033650734, step = 17701 (0.270 sec)
# INFO:tensorflow:global_step/sec: 326.559
# INFO:tensorflow:loss = 0.16564703, step = 17801 (0.306 sec)
# INFO:tensorflow:global_step/sec: 353.651
# INFO:tensorflow:loss = 0.32161364, step = 17901 (0.283 sec)
# INFO:tensorflow:global_step/sec: 425.374
# INFO:tensorflow:loss = 0.08891767, step = 18001 (0.235 sec)
# INFO:tensorflow:global_step/sec: 448.447
# INFO:tensorflow:loss = 0.0867977, step = 18101 (0.223 sec)
# INFO:tensorflow:global_step/sec: 480.375
# INFO:tensorflow:loss = 0.037230693, step = 18201 (0.208 sec)
# INFO:tensorflow:global_step/sec: 430.863
# INFO:tensorflow:loss = 0.09584787, step = 18301 (0.232 sec)
# INFO:tensorflow:global_step/sec: 430.659
# INFO:tensorflow:loss = 0.03616624, step = 18401 (0.232 sec)
# INFO:tensorflow:global_step/sec: 364.893
# INFO:tensorflow:loss = 0.004332806, step = 18501 (0.275 sec)
# INFO:tensorflow:global_step/sec: 396.014
# INFO:tensorflow:loss = 0.11250366, step = 18601 (0.251 sec)
# INFO:tensorflow:global_step/sec: 447.07
# INFO:tensorflow:loss = 0.08822912, step = 18701 (0.224 sec)
# INFO:tensorflow:global_step/sec: 441.971
# INFO:tensorflow:loss = 0.021785941, step = 18801 (0.226 sec)
# INFO:tensorflow:global_step/sec: 443.239
# INFO:tensorflow:loss = 0.012755475, step = 18901 (0.225 sec)
# INFO:tensorflow:global_step/sec: 412.021
# INFO:tensorflow:loss = 0.35376096, step = 19001 (0.243 sec)
# INFO:tensorflow:global_step/sec: 327.105
# INFO:tensorflow:loss = 0.20291592, step = 19101 (0.305 sec)
# INFO:tensorflow:global_step/sec: 340.398
# INFO:tensorflow:loss = 0.1285078, step = 19201 (0.294 sec)
# INFO:tensorflow:global_step/sec: 361.365
# INFO:tensorflow:loss = 0.034109216, step = 19301 (0.277 sec)
# INFO:tensorflow:global_step/sec: 371.234
# INFO:tensorflow:loss = 0.013742149, step = 19401 (0.269 sec)
# INFO:tensorflow:global_step/sec: 409.646
# INFO:tensorflow:loss = 0.06850734, step = 19501 (0.244 sec)
# INFO:tensorflow:global_step/sec: 439.899
# INFO:tensorflow:loss = 0.02765189, step = 19601 (0.227 sec)
# INFO:tensorflow:global_step/sec: 447.722
# INFO:tensorflow:loss = 0.05904875, step = 19701 (0.224 sec)
# INFO:tensorflow:global_step/sec: 428.175
# INFO:tensorflow:loss = 0.052992314, step = 19801 (0.233 sec)
# INFO:tensorflow:global_step/sec: 442.691
# INFO:tensorflow:loss = 0.1395893, step = 19901 (0.226 sec)
# INFO:tensorflow:global_step/sec: 418.006
# INFO:tensorflow:loss = 0.21909072, step = 20001 (0.239 sec)
# INFO:tensorflow:global_step/sec: 385.496
# INFO:tensorflow:loss = 0.023111163, step = 20101 (0.260 sec)
# INFO:tensorflow:global_step/sec: 297.283
# INFO:tensorflow:loss = 0.17262967, step = 20201 (0.336 sec)
# INFO:tensorflow:global_step/sec: 369.595
# INFO:tensorflow:loss = 0.025061034, step = 20301 (0.271 sec)
# INFO:tensorflow:global_step/sec: 390.446
# INFO:tensorflow:loss = 0.015769135, step = 20401 (0.257 sec)
# INFO:tensorflow:global_step/sec: 326.309
# INFO:tensorflow:loss = 0.055396557, step = 20501 (0.306 sec)
# INFO:tensorflow:global_step/sec: 346.293
# INFO:tensorflow:loss = 0.07564549, step = 20601 (0.289 sec)
# INFO:tensorflow:global_step/sec: 435.195
# INFO:tensorflow:loss = 0.025958845, step = 20701 (0.230 sec)
# INFO:tensorflow:global_step/sec: 418.625
# INFO:tensorflow:loss = 0.020951357, step = 20801 (0.238 sec)
# INFO:tensorflow:global_step/sec: 413.663
# INFO:tensorflow:loss = 0.016124343, step = 20901 (0.242 sec)
# INFO:tensorflow:global_step/sec: 394.652
# INFO:tensorflow:loss = 0.1552638, step = 21001 (0.254 sec)
# INFO:tensorflow:global_step/sec: 439.995
# INFO:tensorflow:loss = 0.20021337, step = 21101 (0.227 sec)
# INFO:tensorflow:global_step/sec: 414.468
# INFO:tensorflow:loss = 0.080549225, step = 21201 (0.241 sec)
# INFO:tensorflow:global_step/sec: 403.931
# INFO:tensorflow:loss = 0.034043066, step = 21301 (0.248 sec)
# INFO:tensorflow:global_step/sec: 402.8
# INFO:tensorflow:loss = 0.07418825, step = 21401 (0.247 sec)
# INFO:tensorflow:global_step/sec: 406.567
# INFO:tensorflow:loss = 0.119051225, step = 21501 (0.246 sec)
# INFO:tensorflow:global_step/sec: 403.242
# INFO:tensorflow:loss = 0.06741612, step = 21601 (0.250 sec)
# INFO:tensorflow:global_step/sec: 313.895
# INFO:tensorflow:loss = 0.045229174, step = 21701 (0.317 sec)
# INFO:tensorflow:global_step/sec: 350.334
# INFO:tensorflow:loss = 0.12770632, step = 21801 (0.285 sec)
# INFO:tensorflow:global_step/sec: 339.38
# INFO:tensorflow:loss = 0.1469756, step = 21901 (0.294 sec)
# INFO:tensorflow:global_step/sec: 384.695
# INFO:tensorflow:loss = 0.12361003, step = 22001 (0.260 sec)
# INFO:tensorflow:global_step/sec: 358.355
# INFO:tensorflow:loss = 0.11867477, step = 22101 (0.279 sec)
# INFO:tensorflow:global_step/sec: 476.219
# INFO:tensorflow:loss = 0.037125137, step = 22201 (0.210 sec)
# INFO:tensorflow:global_step/sec: 449.616
# INFO:tensorflow:loss = 0.009425149, step = 22301 (0.222 sec)
# INFO:tensorflow:global_step/sec: 447.516
# INFO:tensorflow:loss = 0.016438652, step = 22401 (0.223 sec)
# INFO:tensorflow:global_step/sec: 459.865
# INFO:tensorflow:loss = 0.030850321, step = 22501 (0.217 sec)
# INFO:tensorflow:global_step/sec: 468.639
# INFO:tensorflow:loss = 0.037362706, step = 22601 (0.214 sec)
# INFO:tensorflow:global_step/sec: 455.489
# INFO:tensorflow:loss = 0.04428557, step = 22701 (0.220 sec)
# INFO:tensorflow:global_step/sec: 458.333
# INFO:tensorflow:loss = 0.012221083, step = 22801 (0.218 sec)
# INFO:tensorflow:global_step/sec: 446.221
# INFO:tensorflow:loss = 0.022762204, step = 22901 (0.224 sec)
# INFO:tensorflow:global_step/sec: 460.963
# INFO:tensorflow:loss = 0.058562417, step = 23001 (0.217 sec)
# INFO:tensorflow:global_step/sec: 472.72
# INFO:tensorflow:loss = 0.23608579, step = 23101 (0.211 sec)
# INFO:tensorflow:global_step/sec: 489.203
# INFO:tensorflow:loss = 0.113321446, step = 23201 (0.205 sec)
# INFO:tensorflow:global_step/sec: 459.51
# INFO:tensorflow:loss = 0.042288624, step = 23301 (0.218 sec)
# INFO:tensorflow:global_step/sec: 460.626
# INFO:tensorflow:loss = 0.0041416604, step = 23401 (0.217 sec)
# INFO:tensorflow:global_step/sec: 468.894
# INFO:tensorflow:loss = 0.056825563, step = 23501 (0.214 sec)
# INFO:tensorflow:global_step/sec: 469.704
# INFO:tensorflow:loss = 0.055856712, step = 23601 (0.212 sec)
# INFO:tensorflow:global_step/sec: 457.205
# INFO:tensorflow:loss = 0.02904511, step = 23701 (0.219 sec)
# INFO:tensorflow:global_step/sec: 466.434
# INFO:tensorflow:loss = 0.012492668, step = 23801 (0.214 sec)
# INFO:tensorflow:global_step/sec: 470.342
# INFO:tensorflow:loss = 0.039861612, step = 23901 (0.213 sec)
# INFO:tensorflow:global_step/sec: 421.1
# INFO:tensorflow:loss = 0.03425716, step = 24001 (0.238 sec)
# INFO:tensorflow:global_step/sec: 459.086
# INFO:tensorflow:loss = 0.04659225, step = 24101 (0.218 sec)
# INFO:tensorflow:global_step/sec: 459.044
# INFO:tensorflow:loss = 0.17080367, step = 24201 (0.217 sec)
# INFO:tensorflow:global_step/sec: 434.109
# INFO:tensorflow:loss = 0.12870106, step = 24301 (0.230 sec)
# INFO:tensorflow:global_step/sec: 485.764
# INFO:tensorflow:loss = 0.011723167, step = 24401 (0.206 sec)
# INFO:tensorflow:global_step/sec: 476.835
# INFO:tensorflow:loss = 0.015193927, step = 24501 (0.210 sec)
# INFO:tensorflow:global_step/sec: 447.008
# INFO:tensorflow:loss = 0.003528231, step = 24601 (0.224 sec)
# INFO:tensorflow:global_step/sec: 448.97
# INFO:tensorflow:loss = 0.03557548, step = 24701 (0.223 sec)
# INFO:tensorflow:global_step/sec: 464.257
# INFO:tensorflow:loss = 0.028250515, step = 24801 (0.215 sec)
# INFO:tensorflow:global_step/sec: 458.377
# INFO:tensorflow:loss = 0.067026116, step = 24901 (0.219 sec)
# INFO:tensorflow:global_step/sec: 476.78
# INFO:tensorflow:loss = 0.01741076, step = 25001 (0.209 sec)
# INFO:tensorflow:global_step/sec: 450.025
# INFO:tensorflow:loss = 0.08320624, step = 25101 (0.222 sec)
# INFO:tensorflow:global_step/sec: 393.812
# INFO:tensorflow:loss = 0.09732489, step = 25201 (0.254 sec)
# INFO:tensorflow:global_step/sec: 477.284
# INFO:tensorflow:loss = 0.03020022, step = 25301 (0.209 sec)
# INFO:tensorflow:global_step/sec: 463.878
# INFO:tensorflow:loss = 0.003174269, step = 25401 (0.216 sec)
# INFO:tensorflow:global_step/sec: 482.509
# INFO:tensorflow:loss = 0.04365947, step = 25501 (0.207 sec)
# INFO:tensorflow:global_step/sec: 469.575
# INFO:tensorflow:loss = 0.09246146, step = 25601 (0.213 sec)
# INFO:tensorflow:global_step/sec: 463.199
# INFO:tensorflow:loss = 0.059653312, step = 25701 (0.216 sec)
# INFO:tensorflow:global_step/sec: 467.388
# INFO:tensorflow:loss = 0.039660577, step = 25801 (0.214 sec)
# INFO:tensorflow:global_step/sec: 467.954
# INFO:tensorflow:loss = 0.034197684, step = 25901 (0.213 sec)
# INFO:tensorflow:global_step/sec: 467.461
# INFO:tensorflow:loss = 0.02706666, step = 26001 (0.214 sec)
# INFO:tensorflow:global_step/sec: 459.394
# INFO:tensorflow:loss = 0.019309128, step = 26101 (0.218 sec)
# INFO:tensorflow:global_step/sec: 465.716
# INFO:tensorflow:loss = 0.099775344, step = 26201 (0.215 sec)
# INFO:tensorflow:global_step/sec: 457.951
# INFO:tensorflow:loss = 0.017238872, step = 26301 (0.218 sec)
# INFO:tensorflow:global_step/sec: 458.911
# INFO:tensorflow:loss = 0.026559625, step = 26401 (0.218 sec)
# INFO:tensorflow:global_step/sec: 449.775
# INFO:tensorflow:loss = 0.06547903, step = 26501 (0.222 sec)
# INFO:tensorflow:global_step/sec: 446.954
# INFO:tensorflow:loss = 0.0585757, step = 26601 (0.224 sec)
# INFO:tensorflow:global_step/sec: 464.181
# INFO:tensorflow:loss = 0.038077075, step = 26701 (0.215 sec)
# INFO:tensorflow:global_step/sec: 469.27
# INFO:tensorflow:loss = 0.06304972, step = 26801 (0.213 sec)
# INFO:tensorflow:global_step/sec: 456.24
# INFO:tensorflow:loss = 0.014163791, step = 26901 (0.219 sec)
# INFO:tensorflow:global_step/sec: 441.226
# INFO:tensorflow:loss = 0.014638259, step = 27001 (0.227 sec)
# INFO:tensorflow:global_step/sec: 460.893
# INFO:tensorflow:loss = 0.061112702, step = 27101 (0.217 sec)
# INFO:tensorflow:global_step/sec: 470.347
# INFO:tensorflow:loss = 0.036786515, step = 27201 (0.212 sec)
# INFO:tensorflow:global_step/sec: 475.581
# INFO:tensorflow:loss = 0.013980376, step = 27301 (0.211 sec)
# INFO:tensorflow:global_step/sec: 457.245
# INFO:tensorflow:loss = 0.051070027, step = 27401 (0.218 sec)
# INFO:tensorflow:global_step/sec: 416.916
# INFO:tensorflow:loss = 0.02430521, step = 27501 (0.240 sec)
# INFO:tensorflow:global_step/sec: 447.669
# INFO:tensorflow:loss = 0.060515508, step = 27601 (0.223 sec)
# INFO:tensorflow:global_step/sec: 469.612
# INFO:tensorflow:loss = 0.02729816, step = 27701 (0.213 sec)
# INFO:tensorflow:global_step/sec: 460.345
# INFO:tensorflow:loss = 0.011574864, step = 27801 (0.217 sec)
# INFO:tensorflow:global_step/sec: 419.064
# INFO:tensorflow:loss = 0.006567635, step = 27901 (0.238 sec)
# INFO:tensorflow:global_step/sec: 458.487
# INFO:tensorflow:loss = 0.05655751, step = 28001 (0.218 sec)
# INFO:tensorflow:global_step/sec: 456.667
# INFO:tensorflow:loss = 0.022074955, step = 28101 (0.220 sec)
# INFO:tensorflow:global_step/sec: 424.836
# INFO:tensorflow:loss = 0.015546057, step = 28201 (0.235 sec)
# INFO:tensorflow:global_step/sec: 410.196
# INFO:tensorflow:loss = 0.019258235, step = 28301 (0.244 sec)
# INFO:tensorflow:global_step/sec: 409.804
# INFO:tensorflow:loss = 0.033983033, step = 28401 (0.244 sec)
# INFO:tensorflow:global_step/sec: 462.12
# INFO:tensorflow:loss = 0.0069053266, step = 28501 (0.217 sec)
# INFO:tensorflow:global_step/sec: 466.322
# INFO:tensorflow:loss = 0.02269628, step = 28601 (0.214 sec)
# INFO:tensorflow:global_step/sec: 425.933
# INFO:tensorflow:loss = 0.010546627, step = 28701 (0.235 sec)
# INFO:tensorflow:global_step/sec: 438.852
# INFO:tensorflow:loss = 0.040623475, step = 28801 (0.228 sec)
# INFO:tensorflow:global_step/sec: 438.658
# INFO:tensorflow:loss = 0.017917927, step = 28901 (0.228 sec)
# INFO:tensorflow:global_step/sec: 419.96
# INFO:tensorflow:loss = 0.0026537976, step = 29001 (0.238 sec)
# INFO:tensorflow:global_step/sec: 420.015
# INFO:tensorflow:loss = 0.027235422, step = 29101 (0.238 sec)
# INFO:tensorflow:global_step/sec: 421.692
# INFO:tensorflow:loss = 0.0074046156, step = 29201 (0.237 sec)
# INFO:tensorflow:global_step/sec: 422.292
# INFO:tensorflow:loss = 0.023558885, step = 29301 (0.237 sec)
# INFO:tensorflow:global_step/sec: 426.146
# INFO:tensorflow:loss = 0.082800314, step = 29401 (0.235 sec)
# INFO:tensorflow:global_step/sec: 402.423
# INFO:tensorflow:loss = 0.0020957661, step = 29501 (0.249 sec)
# INFO:tensorflow:global_step/sec: 379.868
# INFO:tensorflow:loss = 0.10297379, step = 29601 (0.263 sec)
# INFO:tensorflow:global_step/sec: 435.956
# INFO:tensorflow:loss = 0.0878149, step = 29701 (0.229 sec)
# INFO:tensorflow:global_step/sec: 407.853
# INFO:tensorflow:loss = 0.019452926, step = 29801 (0.245 sec)
# INFO:tensorflow:global_step/sec: 417.836
# INFO:tensorflow:loss = 0.03922226, step = 29901 (0.240 sec)
# INFO:tensorflow:global_step/sec: 409.377
# INFO:tensorflow:loss = 0.03345055, step = 30001 (0.244 sec)
# INFO:tensorflow:global_step/sec: 383.892
# INFO:tensorflow:loss = 0.065580666, step = 30101 (0.261 sec)
# INFO:tensorflow:global_step/sec: 419.093
# INFO:tensorflow:loss = 0.051739655, step = 30201 (0.239 sec)
# INFO:tensorflow:global_step/sec: 405.215
# INFO:tensorflow:loss = 0.0041265683, step = 30301 (0.246 sec)
# INFO:tensorflow:global_step/sec: 405.528
# INFO:tensorflow:loss = 0.026926402, step = 30401 (0.247 sec)
# INFO:tensorflow:global_step/sec: 399.96
# INFO:tensorflow:loss = 0.0918385, step = 30501 (0.250 sec)
# INFO:tensorflow:global_step/sec: 404.403
# INFO:tensorflow:loss = 0.04584296, step = 30601 (0.248 sec)
# INFO:tensorflow:global_step/sec: 407.093
# INFO:tensorflow:loss = 0.042268515, step = 30701 (0.246 sec)
# INFO:tensorflow:global_step/sec: 404.667
# INFO:tensorflow:loss = 0.015058945, step = 30801 (0.246 sec)
# INFO:tensorflow:global_step/sec: 405.928
# INFO:tensorflow:loss = 0.028080305, step = 30901 (0.246 sec)
# INFO:tensorflow:global_step/sec: 405.538
# INFO:tensorflow:loss = 0.04086775, step = 31001 (0.247 sec)
# INFO:tensorflow:global_step/sec: 401.118
# INFO:tensorflow:loss = 0.044158734, step = 31101 (0.249 sec)
# INFO:tensorflow:global_step/sec: 396.301
# INFO:tensorflow:loss = 0.04715667, step = 31201 (0.253 sec)
# INFO:tensorflow:global_step/sec: 414.739
# INFO:tensorflow:loss = 0.017246192, step = 31301 (0.241 sec)
# INFO:tensorflow:global_step/sec: 392.149
# INFO:tensorflow:loss = 0.0404019, step = 31401 (0.254 sec)
# INFO:tensorflow:global_step/sec: 400.328
# INFO:tensorflow:loss = 0.02016092, step = 31501 (0.250 sec)
# INFO:tensorflow:global_step/sec: 396.404
# INFO:tensorflow:loss = 0.0062546823, step = 31601 (0.253 sec)
# INFO:tensorflow:global_step/sec: 391.737
# INFO:tensorflow:loss = 0.009574009, step = 31701 (0.255 sec)
# INFO:tensorflow:global_step/sec: 393.172
# INFO:tensorflow:loss = 0.030909207, step = 31801 (0.254 sec)
# INFO:tensorflow:global_step/sec: 398.99
# INFO:tensorflow:loss = 0.029429352, step = 31901 (0.250 sec)
# INFO:tensorflow:global_step/sec: 405.364
# INFO:tensorflow:loss = 0.027703166, step = 32001 (0.247 sec)
# INFO:tensorflow:global_step/sec: 403.484
# INFO:tensorflow:loss = 0.026111199, step = 32101 (0.247 sec)
# INFO:tensorflow:global_step/sec: 396.611
# INFO:tensorflow:loss = 0.0037392834, step = 32201 (0.252 sec)
# INFO:tensorflow:global_step/sec: 396.358
# INFO:tensorflow:loss = 0.053105026, step = 32301 (0.252 sec)
# INFO:tensorflow:global_step/sec: 394.834
# INFO:tensorflow:loss = 0.016659383, step = 32401 (0.253 sec)
# INFO:tensorflow:global_step/sec: 340.336
# INFO:tensorflow:loss = 0.044323243, step = 32501 (0.295 sec)
# INFO:tensorflow:global_step/sec: 400.229
# INFO:tensorflow:loss = 0.0060226107, step = 32601 (0.249 sec)
# INFO:tensorflow:global_step/sec: 390.822
# INFO:tensorflow:loss = 0.109096795, step = 32701 (0.256 sec)
# INFO:tensorflow:global_step/sec: 394.942
# INFO:tensorflow:loss = 0.087847516, step = 32801 (0.253 sec)
# INFO:tensorflow:global_step/sec: 409.401
# INFO:tensorflow:loss = 0.10207161, step = 32901 (0.244 sec)
# INFO:tensorflow:global_step/sec: 396.085
# INFO:tensorflow:loss = 0.015929816, step = 33001 (0.252 sec)
# INFO:tensorflow:global_step/sec: 364.557
# INFO:tensorflow:loss = 0.0014542032, step = 33101 (0.274 sec)
# INFO:tensorflow:global_step/sec: 358.252
# INFO:tensorflow:loss = 0.011732868, step = 33201 (0.279 sec)
# INFO:tensorflow:global_step/sec: 366.508
# INFO:tensorflow:loss = 0.0195713, step = 33301 (0.273 sec)
# INFO:tensorflow:global_step/sec: 379.797
# INFO:tensorflow:loss = 0.020881085, step = 33401 (0.263 sec)
# INFO:tensorflow:global_step/sec: 348.799
# INFO:tensorflow:loss = 0.013957605, step = 33501 (0.287 sec)
# INFO:tensorflow:global_step/sec: 348.439
# INFO:tensorflow:loss = 0.007310557, step = 33601 (0.287 sec)
# INFO:tensorflow:global_step/sec: 370.247
# INFO:tensorflow:loss = 0.044433944, step = 33701 (0.270 sec)
# INFO:tensorflow:global_step/sec: 307.31
# INFO:tensorflow:loss = 0.034101043, step = 33801 (0.326 sec)
# INFO:tensorflow:global_step/sec: 342.433
# INFO:tensorflow:loss = 0.029501148, step = 33901 (0.292 sec)
# INFO:tensorflow:global_step/sec: 349.017
# INFO:tensorflow:loss = 0.030162288, step = 34001 (0.286 sec)
# INFO:tensorflow:global_step/sec: 341.939
# INFO:tensorflow:loss = 0.030229775, step = 34101 (0.292 sec)
# INFO:tensorflow:global_step/sec: 347.797
# INFO:tensorflow:loss = 0.026946474, step = 34201 (0.288 sec)
# INFO:tensorflow:global_step/sec: 322.866
# INFO:tensorflow:loss = 0.06426038, step = 34301 (0.309 sec)
# INFO:tensorflow:global_step/sec: 320.623
# INFO:tensorflow:loss = 0.0019412043, step = 34401 (0.312 sec)
# INFO:tensorflow:global_step/sec: 341.056
# INFO:tensorflow:loss = 0.004442984, step = 34501 (0.293 sec)
# INFO:tensorflow:global_step/sec: 331.571
# INFO:tensorflow:loss = 0.016093852, step = 34601 (0.302 sec)
# INFO:tensorflow:global_step/sec: 332.451
# INFO:tensorflow:loss = 0.024010655, step = 34701 (0.301 sec)
# INFO:tensorflow:global_step/sec: 327.508
# INFO:tensorflow:loss = 0.044323094, step = 34801 (0.305 sec)
# INFO:tensorflow:global_step/sec: 334.626
# INFO:tensorflow:loss = 0.062515244, step = 34901 (0.299 sec)
# INFO:tensorflow:global_step/sec: 301.919
# INFO:tensorflow:loss = 0.019648058, step = 35001 (0.331 sec)
# INFO:tensorflow:global_step/sec: 294.85
# INFO:tensorflow:loss = 0.0014837008, step = 35101 (0.340 sec)
# INFO:tensorflow:global_step/sec: 303.028
# INFO:tensorflow:loss = 0.016954232, step = 35201 (0.330 sec)
# INFO:tensorflow:global_step/sec: 309.177
# INFO:tensorflow:loss = 0.0027192913, step = 35301 (0.324 sec)
# INFO:tensorflow:global_step/sec: 293.958
# INFO:tensorflow:loss = 0.006796399, step = 35401 (0.340 sec)
# INFO:tensorflow:global_step/sec: 316.329
# INFO:tensorflow:loss = 0.001132729, step = 35501 (0.316 sec)
# INFO:tensorflow:global_step/sec: 266.061
# INFO:tensorflow:loss = 0.026250677, step = 35601 (0.376 sec)
# INFO:tensorflow:global_step/sec: 321.662
# INFO:tensorflow:loss = 0.01806814, step = 35701 (0.311 sec)
# INFO:tensorflow:global_step/sec: 321.842
# INFO:tensorflow:loss = 0.008231327, step = 35801 (0.310 sec)
# INFO:tensorflow:global_step/sec: 320.533
# INFO:tensorflow:loss = 0.030792482, step = 35901 (0.312 sec)
# INFO:tensorflow:global_step/sec: 318.607
# INFO:tensorflow:loss = 0.018809065, step = 36001 (0.314 sec)
# INFO:tensorflow:global_step/sec: 316.064
# INFO:tensorflow:loss = 0.023006918, step = 36101 (0.316 sec)
# INFO:tensorflow:global_step/sec: 319.823
# INFO:tensorflow:loss = 0.0048031583, step = 36201 (0.313 sec)
# INFO:tensorflow:global_step/sec: 310.393
# INFO:tensorflow:loss = 0.016293911, step = 36301 (0.322 sec)
# INFO:tensorflow:global_step/sec: 306.983
# INFO:tensorflow:loss = 0.00051729206, step = 36401 (0.326 sec)
# INFO:tensorflow:global_step/sec: 312.641
# INFO:tensorflow:loss = 0.007859739, step = 36501 (0.320 sec)
# INFO:tensorflow:global_step/sec: 312.184
# INFO:tensorflow:loss = 0.006214272, step = 36601 (0.320 sec)
# INFO:tensorflow:global_step/sec: 328.585
# INFO:tensorflow:loss = 0.027265834, step = 36701 (0.304 sec)
# INFO:tensorflow:global_step/sec: 332.896
# INFO:tensorflow:loss = 0.006255071, step = 36801 (0.300 sec)
# INFO:tensorflow:global_step/sec: 309.882
# INFO:tensorflow:loss = 0.016746378, step = 36901 (0.323 sec)
# INFO:tensorflow:global_step/sec: 327.533
# INFO:tensorflow:loss = 0.012888522, step = 37001 (0.305 sec)
# INFO:tensorflow:global_step/sec: 334.512
# INFO:tensorflow:loss = 0.010890665, step = 37101 (0.300 sec)
# INFO:tensorflow:global_step/sec: 337.819
# INFO:tensorflow:loss = 0.0244098, step = 37201 (0.296 sec)
# INFO:tensorflow:global_step/sec: 326.793
# INFO:tensorflow:loss = 0.01647011, step = 37301 (0.306 sec)
# INFO:tensorflow:global_step/sec: 336.393
# INFO:tensorflow:loss = 0.06748235, step = 37401 (0.297 sec)
# INFO:tensorflow:global_step/sec: 328.27
# INFO:tensorflow:loss = 0.022744326, step = 37501 (0.305 sec)
# INFO:tensorflow:global_step/sec: 333.398
# INFO:tensorflow:loss = 0.05246932, step = 37601 (0.300 sec)
# INFO:tensorflow:global_step/sec: 308.377
# INFO:tensorflow:loss = 0.02469864, step = 37701 (0.325 sec)
# INFO:tensorflow:global_step/sec: 318.08
# INFO:tensorflow:loss = 0.03459646, step = 37801 (0.315 sec)
# INFO:tensorflow:global_step/sec: 333.286
# INFO:tensorflow:loss = 0.008070482, step = 37901 (0.300 sec)
# INFO:tensorflow:global_step/sec: 336.484
# INFO:tensorflow:loss = 0.004752075, step = 38001 (0.297 sec)
# INFO:tensorflow:global_step/sec: 319.202
# INFO:tensorflow:loss = 0.020756723, step = 38101 (0.313 sec)
# INFO:tensorflow:global_step/sec: 335.915
# INFO:tensorflow:loss = 0.0031631377, step = 38201 (0.298 sec)
# INFO:tensorflow:global_step/sec: 338.202
# INFO:tensorflow:loss = 0.03751695, step = 38301 (0.296 sec)
# INFO:tensorflow:global_step/sec: 341.123
# INFO:tensorflow:loss = 0.034055598, step = 38401 (0.293 sec)
# INFO:tensorflow:global_step/sec: 336.839
# INFO:tensorflow:loss = 0.019944435, step = 38501 (0.297 sec)
# INFO:tensorflow:global_step/sec: 334.425
# INFO:tensorflow:loss = 0.014851788, step = 38601 (0.299 sec)
# INFO:tensorflow:global_step/sec: 338.601
# INFO:tensorflow:loss = 0.012404786, step = 38701 (0.295 sec)
# INFO:tensorflow:global_step/sec: 334.136
# INFO:tensorflow:loss = 0.013904588, step = 38801 (0.299 sec)
# INFO:tensorflow:global_step/sec: 334.863
# INFO:tensorflow:loss = 0.0063767526, step = 38901 (0.299 sec)
# INFO:tensorflow:global_step/sec: 324.831
# INFO:tensorflow:loss = 0.03419354, step = 39001 (0.309 sec)
# INFO:tensorflow:global_step/sec: 334.118
# INFO:tensorflow:loss = 0.027640887, step = 39101 (0.299 sec)
# INFO:tensorflow:global_step/sec: 333.193
# INFO:tensorflow:loss = 0.0013208734, step = 39201 (0.300 sec)
# INFO:tensorflow:global_step/sec: 338.976
# INFO:tensorflow:loss = 0.0054809265, step = 39301 (0.295 sec)
# INFO:tensorflow:global_step/sec: 333.584
# INFO:tensorflow:loss = 0.006621581, step = 39401 (0.299 sec)
# INFO:tensorflow:global_step/sec: 333.88
# INFO:tensorflow:loss = 0.010727261, step = 39501 (0.299 sec)
# INFO:tensorflow:global_step/sec: 331.384
# INFO:tensorflow:loss = 0.024879023, step = 39601 (0.302 sec)
# INFO:tensorflow:global_step/sec: 334.256
# INFO:tensorflow:loss = 0.03760309, step = 39701 (0.299 sec)
# INFO:tensorflow:global_step/sec: 340.34
# INFO:tensorflow:loss = 0.0057588965, step = 39801 (0.294 sec)
# INFO:tensorflow:global_step/sec: 334.906
# INFO:tensorflow:loss = 0.006526805, step = 39901 (0.299 sec)
# INFO:tensorflow:global_step/sec: 330.805
# INFO:tensorflow:loss = 0.03506893, step = 40001 (0.302 sec)
# INFO:tensorflow:global_step/sec: 331.879
# INFO:tensorflow:loss = 0.097884975, step = 40101 (0.301 sec)
# INFO:tensorflow:global_step/sec: 335.029
# INFO:tensorflow:loss = 0.00983115, step = 40201 (0.298 sec)
# INFO:tensorflow:global_step/sec: 333.03
# INFO:tensorflow:loss = 0.008090529, step = 40301 (0.300 sec)
# INFO:tensorflow:global_step/sec: 330.56
# INFO:tensorflow:loss = 0.030749977, step = 40401 (0.302 sec)
# INFO:tensorflow:global_step/sec: 334.763
# INFO:tensorflow:loss = 0.024525363, step = 40501 (0.299 sec)
# INFO:tensorflow:global_step/sec: 339.22
# INFO:tensorflow:loss = 0.010441951, step = 40601 (0.295 sec)
# INFO:tensorflow:global_step/sec: 344.503
# INFO:tensorflow:loss = 0.037337158, step = 40701 (0.290 sec)
# INFO:tensorflow:global_step/sec: 341.808
# INFO:tensorflow:loss = 0.0031625447, step = 40801 (0.293 sec)
# INFO:tensorflow:global_step/sec: 338.331
# INFO:tensorflow:loss = 0.0033109682, step = 40901 (0.295 sec)
# INFO:tensorflow:global_step/sec: 339.028
# INFO:tensorflow:loss = 0.002617463, step = 41001 (0.295 sec)
# INFO:tensorflow:global_step/sec: 339.368
# INFO:tensorflow:loss = 0.0050139464, step = 41101 (0.295 sec)
# INFO:tensorflow:global_step/sec: 340.464
# INFO:tensorflow:loss = 0.028748997, step = 41201 (0.294 sec)
# INFO:tensorflow:global_step/sec: 339.905
# INFO:tensorflow:loss = 0.01865207, step = 41301 (0.294 sec)
# INFO:tensorflow:global_step/sec: 339.388
# INFO:tensorflow:loss = 0.03206126, step = 41401 (0.294 sec)
# INFO:tensorflow:global_step/sec: 341.155
# INFO:tensorflow:loss = 0.014047624, step = 41501 (0.293 sec)
# INFO:tensorflow:global_step/sec: 340.033
# INFO:tensorflow:loss = 0.032787155, step = 41601 (0.294 sec)
# INFO:tensorflow:global_step/sec: 339.373
# INFO:tensorflow:loss = 0.02072615, step = 41701 (0.295 sec)
# INFO:tensorflow:global_step/sec: 339.393
# INFO:tensorflow:loss = 0.02948567, step = 41801 (0.295 sec)
# INFO:tensorflow:global_step/sec: 340.076
# INFO:tensorflow:loss = 0.0025084848, step = 41901 (0.294 sec)
# INFO:tensorflow:global_step/sec: 340.731
# INFO:tensorflow:loss = 0.026373768, step = 42001 (0.294 sec)
# INFO:tensorflow:global_step/sec: 338.175
# INFO:tensorflow:loss = 0.0068001333, step = 42101 (0.295 sec)
# INFO:tensorflow:global_step/sec: 339.192
# INFO:tensorflow:loss = 0.005073269, step = 42201 (0.295 sec)
# INFO:tensorflow:global_step/sec: 337.446
# INFO:tensorflow:loss = 0.006606941, step = 42301 (0.297 sec)
# INFO:tensorflow:global_step/sec: 339.479
# INFO:tensorflow:loss = 0.0018445025, step = 42401 (0.294 sec)
# INFO:tensorflow:global_step/sec: 339.766
# INFO:tensorflow:loss = 0.009274057, step = 42501 (0.294 sec)
# INFO:tensorflow:global_step/sec: 337.771
# INFO:tensorflow:loss = 0.009583888, step = 42601 (0.296 sec)
# INFO:tensorflow:global_step/sec: 342.184
# INFO:tensorflow:loss = 0.04011241, step = 42701 (0.292 sec)
# INFO:tensorflow:global_step/sec: 339.439
# INFO:tensorflow:loss = 0.013664583, step = 42801 (0.295 sec)
# INFO:tensorflow:global_step/sec: 336.673
# INFO:tensorflow:loss = 0.011690152, step = 42901 (0.297 sec)
# INFO:tensorflow:global_step/sec: 335.488
# INFO:tensorflow:loss = 0.01378352, step = 43001 (0.298 sec)
# INFO:tensorflow:global_step/sec: 336.866
# INFO:tensorflow:loss = 0.0064056204, step = 43101 (0.297 sec)
# INFO:tensorflow:global_step/sec: 338.706
# INFO:tensorflow:loss = 0.01931613, step = 43201 (0.295 sec)
# INFO:tensorflow:global_step/sec: 337.331
# INFO:tensorflow:loss = 0.0008115834, step = 43301 (0.297 sec)
# INFO:tensorflow:global_step/sec: 337.522
# INFO:tensorflow:loss = 0.003179969, step = 43401 (0.296 sec)
# INFO:tensorflow:global_step/sec: 343.222
# INFO:tensorflow:loss = 0.022779176, step = 43501 (0.291 sec)
# INFO:tensorflow:global_step/sec: 336.192
# INFO:tensorflow:loss = 0.016859025, step = 43601 (0.298 sec)
# INFO:tensorflow:global_step/sec: 321.553
# INFO:tensorflow:loss = 0.021548543, step = 43701 (0.311 sec)
# INFO:tensorflow:global_step/sec: 279.706
# INFO:tensorflow:loss = 0.021482183, step = 43801 (0.357 sec)
# INFO:tensorflow:global_step/sec: 269.702
# INFO:tensorflow:loss = 0.029792547, step = 43901 (0.372 sec)
# INFO:tensorflow:Saving checkpoints for 44000 into /var/folders/1g/rftmf6dn1g5dkx80h4m74syc0000gn/T/tmpo3tv44x1/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0070964578.

# %%
test_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"X": X_test}, y=y_test, shuffle=False)
eval_results = dnn_clf.evaluate(input_fn=test_input_fn)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-30-07:37:04
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/1g/rftmf6dn1g5dkx80h4m74syc0000gn/T/tmpo3tv44x1/model.ckpt-44000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-07-30-07:37:04
# INFO:tensorflow:Saving dict for global step 44000: accuracy = 0.9796, average_loss = 0.104513876, global_step = 44000, loss = 13.229605

# %%
eval_results
# Out:
# {'accuracy': 0.9796,
#  'average_loss': 0.104513876,
#  'loss': 13.229605,
#  'global_step': 44000}

# %%
y_pred_iter = dnn_clf.predict(input_fn=test_input_fn)
y_pred = list(y_pred_iter)
y_pred[0]
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/1g/rftmf6dn1g5dkx80h4m74syc0000gn/T/tmpo3tv44x1/model.ckpt-44000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# {'logits': array([ -8.205022 ,  -6.533808 ,  -8.937283 ,  -1.8526587, -14.142021 ,
#          -8.1129675, -14.956382 ,  18.110773 ,  -5.9473   ,   3.0048811],
#        dtype=float32),
#  'probabilities': array([3.7255893e-12, 1.9815016e-11, 1.7913422e-12, 2.1379198e-09,
#         9.8353578e-15, 4.0848349e-12, 4.3562964e-15, 9.9999976e-01,
#         3.5621447e-11, 2.7516569e-07], dtype=float32),
#  'class_ids': array([7]),
#  'classes': array([b'7'], dtype=object)}

# %% [markdown]
# ## 10.3 텐서플로의 저수준 API로 심층 신경망 훈련하기

# %% [markdown]
# ### 10.3.1 구성 단계

# %% [markdown]
# 입력, 출력크기, 은닉층의 뉴런 수 설정

# %%
import tensorflow as tf

n_inputs = 28 * 28 # MNIST
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

# %%
reset_graph()

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name='X')
y = tf.placeholder(tf.int32, shape=(None), name='y')

# %%
def neuron_layer(X, n_neurons, name, activation=None):
    with tf.name_scope(name):
        n_inputs = int(X.get_shape()[1])
        stddev = 2 / np.sqrt(n_inputs + n_neurons)
        init = tf.truncated_normal((n_inputs, n_neurons), stddev=stddev)
        W = tf.Variable(init, name='kernel')
        b = tf.Variable(tf.zeros([n_neurons]), name='bias')
        Z = tf.matmul(X, W) + b
        if activation is not None:
            return activation(Z)
        else:
            return Z

# %% [markdown]
# 1. 층 이름으로 이름 범위를 만든다.
# 2. 입력 행렬의 크기에서 두 번째 차원을 사용해 입력 특성의 수를 구한다.
# 3. 가중치 행렬을 담을 W 변수를 만든다. 입력과 각 뉴런 사이의 연결 가중치를 담고 있는 2D 텐서이니 크기는 (n\_inputs, n\_neurons)가 된다. 이 행렬은 표준편차가 $\frac{2}{\sqrt{n_{inputs}+n_{neurons}}}$ 인 절단 정규 가우시안 분포(truncated normal distribution)을 사용해 무작위로 초기화한다. 이 표준편차를 사용하면 알고리즘이 훨씬 빠르게 수렴한다. 경사 하강법 알고리즘이 중단되지 않돌고 대칭성을 피하기 위해 모든 은닉층의 가중치는 무작위로 초기화하는 것이 중요하다.
# 4. 뉴런마다 하나의 편향을 갖도록 변수 b를 만들고 0으로 초기화한다.
# 5. Z = X$\cdot$W + b 를 계산하기 위한 그래프를 만든다. 이 벡터화된 구현은 층에 있는 모든 뉴런과 배치에 있는 모든 샘플에 대해 입력에 대한 가중치 합에 편향을 더하는 계산을 효율적으로 한방에 수행한다.
# 6. 마지막으로 activation(Z)을 반환하고, 그렇지 않으면 그냥 Z를 반환한다

# %%
with tf.name_scope("dnn"):
    hidden1 = neuron_layer(X, n_hidden1, name='hidden1', activation=tf.nn.relu)
    hidden2 = neuron_layer(hidden1, n_hidden2, name='hidden2', activation=tf.nn.relu)
    logits = neuron_layer(hidden2, n_outputs, name='outputs')

# %% [markdown]
# logits은 소프트맥스 활성화함수로 들어가기 **직전의** 신경망 출력이다.

# %% [markdown]
# 텐서플로의 tf.layers.dense() 는 모든 입력이 은닉층에 있는 모든 뉴런과 연결된 완전 연결층(fully connected layer)을 만든다. 이 함수는 적절한 초기화 방식을 사용해 kernel과 bias라는 이름으로 가중치와 편향 변수를 만든다.

# %%
with tf.name_scope('dnn'):
    hidden1 = tf.layers.dense(X, n_hidden1, name='hidden1', activation=tf.nn.relu)
    hidden2 = tf.layers.dense(hidden1, n_hidden2, name='hidden2', activation=tf.nn.relu)
    logits = tf.layers.dense(hidden2, n_outputs, name='outputs')

# %%
with tf.name_scope('loss'):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name='loss')

# %%
learning_rate = 0.01

with tf.name_scope('train'):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %% [markdown]
# 평가 방법을 지정한다. 여기서는 간단하게 정확도를 사용해 성능을 측정한다. 먼저 샘플마다 가장 큰 로짓이 타깃 클래스에 해당하는지 여부를 확인해 신경망의 예측이 맞는지 결정한다. 이를 위해 in\_top\_k() 함수를 사용한다. in\_top\_k(predictions, targets, k) 함수는 예측값(predictions)과 타깃 레이블(targets)을 입력받아 타깃 레이블의 예측값이 크기순으로 k번째 안에 들면 True, 그렇지 않으면 False를 반환한다.

# %%
with tf.name_scope('eval'):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %% [markdown]
# ### 10.3.2 실행 단계

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('/tmp/data/')
# Out:
# WARNING:tensorflow:From <ipython-input-51-54368a95c440>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /Users/smfc/.pyenv/versions/3.6.4/envs/hands-on/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /Users/smfc/.pyenv/versions/3.6.4/envs/hands-on/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /Users/smfc/.pyenv/versions/3.6.4/envs/hands-on/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /Users/smfc/.pyenv/versions/3.6.4/envs/hands-on/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/smfc/.pyenv/versions/3.6.4/envs/hands-on/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %% [markdown]
# # 에포크(epoch) 횟수와 미니배치 크기를 정의하자

# %%
n_epochs = 40
batch_size = 50

# %% [markdown]
# 모델 훈련

# %%
def shuffle_batch(X, y, batch_size):
    rnd_idx = np.random.permutation(len(X))
    n_batches = len(X) // batch_size
    for batch_idx in np.array_split(rnd_idx, n_batches):
        X_batch, y_batch = X[batch_idx], y[batch_idx]
        yield X_batch, y_batch

# %%
with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train, y_train, batch_size):
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_batch = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_val = accuracy.eval(feed_dict={X: X_valid, y: y_valid})
        print(epoch, "Batch accuracy:", acc_batch, "Val accuracy:", acc_val)

    save_path = saver.save(sess, "./my_model_final_cp10.ckpt")
# Out:
# 0 Batch accuracy: 0.9 Val accuracy: 0.9024
# 1 Batch accuracy: 0.92 Val accuracy: 0.9254
# 2 Batch accuracy: 0.94 Val accuracy: 0.9372
# 3 Batch accuracy: 0.9 Val accuracy: 0.9416
# 4 Batch accuracy: 0.94 Val accuracy: 0.9472
# 5 Batch accuracy: 0.94 Val accuracy: 0.9512
# 6 Batch accuracy: 1.0 Val accuracy: 0.9548
# 7 Batch accuracy: 0.94 Val accuracy: 0.961
# 8 Batch accuracy: 0.96 Val accuracy: 0.9622
# 9 Batch accuracy: 0.94 Val accuracy: 0.9648
# 10 Batch accuracy: 0.92 Val accuracy: 0.9656
# 11 Batch accuracy: 0.98 Val accuracy: 0.9666
# 12 Batch accuracy: 0.98 Val accuracy: 0.9684
# 13 Batch accuracy: 0.98 Val accuracy: 0.9704
# 14 Batch accuracy: 1.0 Val accuracy: 0.9694
# 15 Batch accuracy: 0.94 Val accuracy: 0.9718
# 16 Batch accuracy: 0.98 Val accuracy: 0.9726
# 17 Batch accuracy: 1.0 Val accuracy: 0.9728
# 18 Batch accuracy: 0.98 Val accuracy: 0.9744
# 19 Batch accuracy: 0.98 Val accuracy: 0.9758
# 20 Batch accuracy: 1.0 Val accuracy: 0.9748
# 21 Batch accuracy: 1.0 Val accuracy: 0.9734
# 22 Batch accuracy: 0.96 Val accuracy: 0.9752
# 23 Batch accuracy: 0.98 Val accuracy: 0.9764
# 24 Batch accuracy: 0.98 Val accuracy: 0.976
# 25 Batch accuracy: 1.0 Val accuracy: 0.9762
# 26 Batch accuracy: 0.92 Val accuracy: 0.9768
# 27 Batch accuracy: 1.0 Val accuracy: 0.9778
# 28 Batch accuracy: 0.94 Val accuracy: 0.978
# 29 Batch accuracy: 1.0 Val accuracy: 0.9778
# 30 Batch accuracy: 1.0 Val accuracy: 0.9776
# 31 Batch accuracy: 1.0 Val accuracy: 0.978
# 32 Batch accuracy: 0.96 Val accuracy: 0.9778
# 33 Batch accuracy: 0.98 Val accuracy: 0.9784
# 34 Batch accuracy: 0.98 Val accuracy: 0.9784
# 35 Batch accuracy: 1.0 Val accuracy: 0.9784
# 36 Batch accuracy: 1.0 Val accuracy: 0.9792
# 37 Batch accuracy: 1.0 Val accuracy: 0.9786
# 38 Batch accuracy: 0.98 Val accuracy: 0.9798
# 39 Batch accuracy: 1.0 Val accuracy: 0.9786

# %% [markdown]
# ### 10.3.3 신경망 사용하기

# %%
with tf.Session() as sess:
    saver.restore(sess, "./my_model_final_cp10.ckpt") # or better, use save_path
    X_new_scaled = X_test[:20]
    Z = logits.eval(feed_dict={X: X_new_scaled})
    y_pred = np.argmax(Z, axis=1)
# Out:
# INFO:tensorflow:Restoring parameters from ./my_model_final_cp10.ckpt

# %% [markdown]
# 1. 먼저 디스크로부터 모델 파라미터를 읽어 들인다.
# 2. 분류한려는 새 이미지를 읽는다.
#     - 여기서에는 0과 1사이로 훈련 데이터와 같은 스케일로 이미 조정이 되어 있다.
# 3. logits 노드를 평가한다.
# 4. 모든 클래스에 대한 추정 확률을 알고 싶다면 로짓에 softmax() 함수를 적용하면 된다. 다만 로짓 값이 가장 큰 클래스를 선택하려면 argmax를 사용한다.

# %% [markdown]
# ## 10.4 신경망 하이퍼파라미터 튜닝하기

# %% [markdown]
# 그리드 서치의 경우 오랜 시간이 걸리니 랜덤 탐색이 낫다. 혹은 좋은 하이퍼라라미터 조합을 빠르게 찾아주는 복잡한 알고리즘들을 구현한 오스카 같은 도구를 사용하자.

# %% [markdown]
# ### 10.4.1 은닉층의 수

# %% [markdown]
# 은닉층이 하나라도 뉴런의 수가 많으면 복잡한 함수도 모델링할 수 있다. 하지만 심층 신경망이 얕은 신경망보다 **파라미터 효율성**이 훨씬 좋다. 또한 아래쪽 은닉층은 저수준의 구조를 모델링하고 중간 은닉층은 저수준의 구조를 연결하여 중간 수준의 구조를 모델링하고, 위족 은닉층과 춫ㄹ력층은 이런 중간 수준의 구조를 연결하여 고수준의 구조를 모델링한다.
#
# 이런 계층 구조는 심층 신경망이 좋은 솔루션으로 빨리 수렴하게끔 도와주고 새로운 데이터에 일반화되는 능력도 향상시켜준다. 가령 사진에서 얼굴을 인식하는 모델을 훈련시키려 한다면 첫 번째 네트워크의 하위층을 재사용하여 훈련을 시작할수 있다. 새로운 신경망의 처음 몇 개 층의 가중치와 편향을 나눗로 초기화하는 대신 첫 번째 신경망의 층에 있는 가중치와 편향 값으로 초기화할 수 있다.

# %% [markdown]
# ### 10.4.2 은닉층의 뉴런 수

# %% [markdown]
# 은닉층의 구성 방식은 일반적으로 각 층의 뉴런을 점점 줄여서 깔때기처럼 구성한다. 저수준의 많은 특성이 고수준의 적은 특성으로 합쳐질 수 있기 때문이다. 하지만 요즘은 모든 은닉층에 같은 크기를 사용한다. 예를 들어 모든 은닉층에 150개의 뉴런을 둔다. 즉, 하이퍼파라미터가 층마다 따로 있지 않아서 전체를 통틀어 하나만 조정하면 된다. 층의 개수와 마찬가지로 네트워크가 과대적합이 되기 전까지 점진적으로 뉴런 수를 늘린다. 일반적으로 층의 뉴런 수보다 층 수를 늘리는 쪽이 이득이 더 많다. 하지만 완벽한 뉴런 수를 찾는 것은 매우 어렵다.
#
# 실제 필요한 것보다 더 많은 층과 뉴런을 가진 모델을 선택하고, 과대적합되지 않도록 조기 종료기법을 사용하는 방법이 있는데, 이를 '스트래치 팬츠' 방식이라 부른다. 즉, 나에게 맞는 사이즈의 바지를 사는 찾느라 시간을 낭비하는 대신, 그냥 큰 스트레치 팬츠를 사는 것이다.

# %% [markdown]
# ### 10.4.3 활성화 함수

# %% [markdown]
# 대부분의 경우 은닉층에 ReLU 활성화 함수를 사용한다. 이 함수는 다른 활성화 함수보다 계산이 조금 더 빠르고, 입력값이 클수록 특정 값에 수렴하지 않는 덕분에 경사 하강법이 평편한 지역에서 심하게 지체되지 않는다. (로지스틱 함수와 하이퍼볼릭 탄젠트 함수는 1에 수렴한다.)
#
# 출력층에서는 소프트맥스 활성화 함수가 일반적으로 분류 작업에서 사용된다. 회귀 작업인 경우 활성화 함수를 사용하지 않는다.
